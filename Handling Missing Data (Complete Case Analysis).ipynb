# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pmgho'

# %%
os.chdir('C:\\Users\\pmgho\\Downloads\\prajwal_main_data\\')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pmgho\\Downloads\\prajwal_main_data'

# %%
df=pd.read_csv('data_science_job.csv')
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
df.shape
# Out:
# (19158, 13)

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.5 and df[var].isnull().mean() > 0]
cols
# Out:
# ['city_development_index',
#  'gender',
#  'enrolled_university',
#  'education_level',
#  'major_discipline',
#  'experience',
#  'company_size',
#  'company_type',
#  'training_hours']

# %%
len(df[cols].dropna()) / len(df)
# Out:
# 0.44023384486898426

# %%
new_df = df[cols].dropna()
df.shape, new_df.shape
# Out:
# ((19158, 13), (8434, 9))

# %%
new_df.hist(bins=50,density=True,figsize=(12,12))
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['training_hours'].hist(bins=50, ax=ax, density=True, color='red')

# Data after caa, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distribustions
new_df['training_hours'].hist(bins=50,ax=ax,color='green',density=True,alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['training_hours'].plot.density(color='red')
# Data after cca
new_df['training_hours'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['city_development_index'].hist(bins=50, ax=ax, density=True, color='red')

# Data after caa, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distribustions
new_df['city_development_index'].hist(bins=50,ax=ax,color='green',density=True,alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data - corrected 'density' parameter (it's not needed for plot.density)
df['city_development_index'].plot.density(color='red')

# Data after caa - corrected color typo ('gree' -> 'green') and added alpha parameter
new_df['city_development_index'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['experience'].hist(bins=50, ax=ax, density=True, color='red')

# Data after caa, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distribustions
new_df['experience'].hist(bins=50,ax=ax,color='green',density=True,alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original data
df['experience'].plot.density(color='red')

# Data after caa, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distribustions
new_df['experience'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: count, dtype: int64

# %%
temp = pd.concat([
    # percentage of observation per category, original data
    (df['enrolled_university'].value_counts() / len(df)).to_frame('original'),
    
    # percentage of observation per category, cca data
    (new_df['enrolled_university'].value_counts() / len(new_df)).to_frame('cca')
], axis=1)

# %%
# add column names

temp.columns=['original','cca']
temp
# Out:
#                      original       cca
# enrolled_university
# no_enrollment        0.721213  0.848233
# Full time course     0.196106  0.092246
# Part time course     0.062533  0.059521

# %%
temp = pd.concat([
    # percentage of observations per category, original data
    df['education_level'].value_counts() / len(df),
    # percentage of observation per category, cca data
    new_df['education_level'].value_counts() / len(new_df)
    ],axis=1)
# add column names
temp.columns = ['original','cca']
temp
# Out:
#                  original       cca
# education_level
# Graduate         0.605387  0.698245
# Masters          0.227633  0.273180
# High School      0.105282       NaN
# Phd              0.021610  0.028575
# Primary School   0.016077       NaN
